# %%
# Matplotlib
# Las más popular
# Control de todos los aspectos del gráfico
# Similar a la creación de graficos en Matlab
# matplotlib.org (presentación, ejemplos)

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Usuario\anaconda3
#
#   added / updated specs:
#     - matplotlib
#
# Note: you may need to restart the kernel to use updated packages.
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.1                |   py38haa95532_0         2.9 MB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.5-py38_0 --> 4.9.1-py38haa95532_0
#
#
#
# ...
#
# conda-4.9.1          | 2.9 MB    |            |   0%
# conda-4.9.1          | 2.9 MB    |            |   1%
# conda-4.9.1          | 2.9 MB    | ####3      |  44%
# conda-4.9.1          | 2.9 MB    | #########6 |  96%
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Funcional

plt.plot(x,y)
plt.show() # print de los gráficos

# %%
plt.plot(x,y,'r-')
plt.xlabel('Título del eje X')
plt.ylabel('Título del eje Y')
plt.title('Titulo del gráfico')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'b-')

plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
??plt.subplot

# %%
# Imaginemos que es un gráfico en blanco

fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height (range 0 to 1)

axes.plot(x,y)
axes.set_xlabel('Variable X')
axes.set_ylabel('Variable Y')
axes.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes1.set_title('Gráfico grande')
axes1.set_xlabel('Variable del eje X')
axes1.set_ylabel('Variable   del eje Y')

axes2.plot(y,x)
axes2.set_title('Gráfico pequeño')
axes2.set_xlabel('Variable del eje X')
axes2.set_ylabel('Variable del eje Y')
# Out:
# Text(0, 0.5, 'Variable del eje Y')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y)
axes[1].plot(x,y)

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig    
plt.tight_layout()
